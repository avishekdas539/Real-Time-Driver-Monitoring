# %% [markdown]
# # Data and Label Processing

# %% [markdown]
# ## 1.1 Extract the zip files

# %%
import glob
import zipfile

# %%
for file in glob.glob("*.zip"): # Extract all the downloaded zip file
    print("Started Extracting", file)
    try:
        with zipfile.ZipFile(file) as f:
            f.extractall()
        print("Ended Extracting", file)
    except Exception as e:
        print(e, file)
# Out:
# Started Extracting s1.zip
#
# Ended Extracting s1.zip
#
# Started Extracting s2.zip
#
# Ended Extracting s2.zip
#
# Started Extracting s3.zip
#
# Ended Extracting s3.zip
#
# Started Extracting s4 (2).zip
#
# File is not a zip file s4 (2).zip
#
# Started Extracting s5.zip
#
# Ended Extracting s5.zip
#
# Started Extracting s6.zip
#
# Ended Extracting s6.zip

# %% [markdown]
# ## 1.2 Explore The Lables

# %%
import json

# %%
with open("s1/gB_9_s1_2019-03-07T16;36;24+01;00_rgb_ann_distraction.json", "r") as f:
    j = json.load(f)

# %%
j.keys()
# Out:
# dict_keys(['vcd'])

# %%
j["vcd"]["actions"] # Check the labels
# Out:
# {'0': {'name': '',
#   'type': 'gaze_on_road/looking_road',
#   'frame_intervals': [{'frame_start': 0, 'frame_end': 506},
#    {'frame_start': 526, 'frame_end': 537},
#    {'frame_start': 566, 'frame_end': 579},
#    {'frame_start': 608, 'frame_end': 621},
#    {'frame_start': 662, 'frame_end': 694},
#    {'frame_start': 719, 'frame_end': 736},
#    {'frame_start': 746, 'frame_end': 779},
#    {'frame_start': 798, 'frame_end': 810},
#    {'frame_start': 822, 'frame_end': 857},
#    {'frame_start': 868, 'frame_end': 1307},
#    {'frame_start': 1332, 'frame_end': 1464},
#    {'frame_start': 1483, 'frame_end': 1835},
#    {'frame_start': 1937, 'frame_end': 2029},
#    {'frame_start': 2065, 'frame_end': 2079},
#    {'frame_start': 2115, 'frame_end': 2164},
#    {'frame_start': 2216, 'frame_end': 2265},
#    {'frame_start': 2306, 'frame_end': 2312},
#    {'frame_start': 2370, 'frame_end': 2472},
#    {'frame_start': 2509, 'frame_end': 2938},
#    {'frame_start': 2960, 'frame_end': 3008},
#    {'frame_start': 3034, 'frame_end': 3174},
#    {'frame_start': 3197, 'frame_end': 3382},
#    {'frame_start': 3437, 'frame_end': 3456},
#    {'frame_start': 3499, 'frame_end': 3519},
#    {'frame_start': 3542, 'frame_end': 3557},
#    {'frame_start': 3586, 'frame_end': 3601},
#    {'frame_start': 3617, 'frame_end': 3751},
#    {'frame_start': 3771, 'frame_end': 3788},
#    {'frame_start': 3810, 'frame_end': 3860},
#    {'frame_start': 3874, 'frame_end': 4234},
#    {'frame_start': 4252, 'frame_end': 4387},
#    {'frame_start': 4401, 'frame_end': 4509},
#    {'frame_start': 4531, 'frame_end': 5110},
#    {'frame_start': 5139, 'frame_end': 5214},
#    {'frame_start': 5243, 'frame_end': 5297},
#    {'frame_start': 5323, 'frame_end': 5347},
#    {'frame_start': 5364, 'frame_end': 5519},
#    {'frame_start': 5546, 'frame_end': 5596},
#    {'frame_start': 5614, 'frame_end': 5715},
#    {'frame_start': 5732, 'frame_end': 5752},
#    {'frame_start': 5768, 'frame_end': 5787},
#    {'frame_start': 5811, 'frame_end': 5858},
#    {'frame_start': 5885, 'frame_end': 5892},
#    {'frame_start': 5910, 'frame_end': 6887},
#    {'frame_start': 6909, 'frame_end': 7137}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 0, 'frame_end': 506},
#      {'frame_start': 526, 'frame_end': 537},
#      {'frame_start': 566, 'frame_end': 579},
#      {'frame_start': 608, 'frame_end': 621},
#      {'frame_start': 662, 'frame_end': 694},
#      {'frame_start': 719, 'frame_end': 736},
#      {'frame_start': 746, 'frame_end': 779},
#      {'frame_start': 798, 'frame_end': 810},
#      {'frame_start': 822, 'frame_end': 857},
#      {'frame_start': 868, 'frame_end': 1307},
#      {'frame_start': 1332, 'frame_end': 1464},
#      {'frame_start': 1483, 'frame_end': 1835},
#      {'frame_start': 1937, 'frame_end': 2029},
#      {'frame_start': 2065, 'frame_end': 2079},
#      {'frame_start': 2115, 'frame_end': 2164},
#      {'frame_start': 2216, 'frame_end': 2265},
#      {'frame_start': 2306, 'frame_end': 2312},
#      {'frame_start': 2370, 'frame_end': 2472},
#      {'frame_start': 2509, 'frame_end': 2938},
#      {'frame_start': 2960, 'frame_end': 3008},
#      {'frame_start': 3034, 'frame_end': 3174},
#      {'frame_start': 3197, 'frame_end': 3382},
#      {'frame_start': 3437, 'frame_end': 3456},
#      {'frame_start': 3499, 'frame_end': 3519},
#      {'frame_start': 3542, 'frame_end': 3557},
#      {'frame_start': 3586, 'frame_end': 3601},
#      {'frame_start': 3617, 'frame_end': 3751},
#      {'frame_start': 3771, 'frame_end': 3788},
#      {'frame_start': 3810, 'frame_end': 3860},
#      {'frame_start': 3874, 'frame_end': 4234},
#      {'frame_start': 4252, 'frame_end': 4387},
#      {'frame_start': 4401, 'frame_end': 4509},
#      {'frame_start': 4531, 'frame_end': 5110},
#      {'frame_start': 5139, 'frame_end': 5214},
#      {'frame_start': 5243, 'frame_end': 5297},
#      {'frame_start': 5323, 'frame_end': 5347},
#      {'frame_start': 5364, 'frame_end': 5519},
#      {'frame_start': 5546, 'frame_end': 5596},
#      {'frame_start': 5614, 'frame_end': 5715},
#      {'frame_start': 5732, 'frame_end': 5752},
#      {'frame_start': 5768, 'frame_end': 5787},
#      {'frame_start': 5811, 'frame_end': 5858},
#      {'frame_start': 5885, 'frame_end': 5892},
#      {'frame_start': 5910, 'frame_end': 6887},
#      {'frame_start': 6909, 'frame_end': 7137}]}}},
#  '1': {'name': '',
#   'type': 'gaze_on_road/not_looking_road',
#   'frame_intervals': [{'frame_start': 507, 'frame_end': 525},
#    {'frame_start': 538, 'frame_end': 565},
#    {'frame_start': 580, 'frame_end': 607},
#    {'frame_start': 622, 'frame_end': 661},
#    {'frame_start': 695, 'frame_end': 718},
#    {'frame_start': 737, 'frame_end': 745},
#    {'frame_start': 780, 'frame_end': 797},
#    {'frame_start': 811, 'frame_end': 821},
#    {'frame_start': 858, 'frame_end': 867},
#    {'frame_start': 1308, 'frame_end': 1331},
#    {'frame_start': 1465, 'frame_end': 1482},
#    {'frame_start': 1836, 'frame_end': 1936},
#    {'frame_start': 2030, 'frame_end': 2064},
#    {'frame_start': 2080, 'frame_end': 2114},
#    {'frame_start': 2165, 'frame_end': 2215},
#    {'frame_start': 2266, 'frame_end': 2305},
#    {'frame_start': 2313, 'frame_end': 2369},
#    {'frame_start': 2473, 'frame_end': 2508},
#    {'frame_start': 2939, 'frame_end': 2959},
#    {'frame_start': 3009, 'frame_end': 3033},
#    {'frame_start': 3175, 'frame_end': 3196},
#    {'frame_start': 3383, 'frame_end': 3436},
#    {'frame_start': 3457, 'frame_end': 3498},
#    {'frame_start': 3520, 'frame_end': 3541},
#    {'frame_start': 3558, 'frame_end': 3585},
#    {'frame_start': 3602, 'frame_end': 3616},
#    {'frame_start': 3752, 'frame_end': 3770},
#    {'frame_start': 3789, 'frame_end': 3809},
#    {'frame_start': 3861, 'frame_end': 3873},
#    {'frame_start': 4235, 'frame_end': 4251},
#    {'frame_start': 4388, 'frame_end': 4400},
#    {'frame_start': 4510, 'frame_end': 4530},
#    {'frame_start': 5111, 'frame_end': 5138},
#    {'frame_start': 5215, 'frame_end': 5242},
#    {'frame_start': 5298, 'frame_end': 5322},
#    {'frame_start': 5348, 'frame_end': 5363},
#    {'frame_start': 5520, 'frame_end': 5545},
#    {'frame_start': 5597, 'frame_end': 5613},
#    {'frame_start': 5716, 'frame_end': 5731},
#    {'frame_start': 5753, 'frame_end': 5767},
#    {'frame_start': 5788, 'frame_end': 5810},
#    {'frame_start': 5859, 'frame_end': 5884},
#    {'frame_start': 5893, 'frame_end': 5909},
#    {'frame_start': 6888, 'frame_end': 6908}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 507, 'frame_end': 525},
#      {'frame_start': 538, 'frame_end': 565},
#      {'frame_start': 580, 'frame_end': 607},
#      {'frame_start': 622, 'frame_end': 661},
#      {'frame_start': 695, 'frame_end': 718},
#      {'frame_start': 737, 'frame_end': 745},
#      {'frame_start': 780, 'frame_end': 797},
#      {'frame_start': 811, 'frame_end': 821},
#      {'frame_start': 858, 'frame_end': 867},
#      {'frame_start': 1308, 'frame_end': 1331},
#      {'frame_start': 1465, 'frame_end': 1482},
#      {'frame_start': 1836, 'frame_end': 1936},
#      {'frame_start': 2030, 'frame_end': 2064},
#      {'frame_start': 2080, 'frame_end': 2114},
#      {'frame_start': 2165, 'frame_end': 2215},
#      {'frame_start': 2266, 'frame_end': 2305},
#      {'frame_start': 2313, 'frame_end': 2369},
#      {'frame_start': 2473, 'frame_end': 2508},
#      {'frame_start': 2939, 'frame_end': 2959},
#      {'frame_start': 3009, 'frame_end': 3033},
#      {'frame_start': 3175, 'frame_end': 3196},
#      {'frame_start': 3383, 'frame_end': 3436},
#      {'frame_start': 3457, 'frame_end': 3498},
#      {'frame_start': 3520, 'frame_end': 3541},
#      {'frame_start': 3558, 'frame_end': 3585},
#      {'frame_start': 3602, 'frame_end': 3616},
#      {'frame_start': 3752, 'frame_end': 3770},
#      {'frame_start': 3789, 'frame_end': 3809},
#      {'frame_start': 3861, 'frame_end': 3873},
#      {'frame_start': 4235, 'frame_end': 4251},
#      {'frame_start': 4388, 'frame_end': 4400},
#      {'frame_start': 4510, 'frame_end': 4530},
#      {'frame_start': 5111, 'frame_end': 5138},
#      {'frame_start': 5215, 'frame_end': 5242},
#      {'frame_start': 5298, 'frame_end': 5322},
#      {'frame_start': 5348, 'frame_end': 5363},
#      {'frame_start': 5520, 'frame_end': 5545},
#      {'frame_start': 5597, 'frame_end': 5613},
#      {'frame_start': 5716, 'frame_end': 5731},
#      {'frame_start': 5753, 'frame_end': 5767},
#      {'frame_start': 5788, 'frame_end': 5810},
#      {'frame_start': 5859, 'frame_end': 5884},
#      {'frame_start': 5893, 'frame_end': 5909},
#      {'frame_start': 6888, 'frame_end': 6908}]}}},
#  '2': {'name': '',
#   'type': 'talking/talking',
#   'frame_intervals': [{'frame_start': 1842, 'frame_end': 1857},
#    {'frame_start': 1878, 'frame_end': 1922},
#    {'frame_start': 2071, 'frame_end': 2235},
#    {'frame_start': 2283, 'frame_end': 2295},
#    {'frame_start': 2328, 'frame_end': 2337},
#    {'frame_start': 2419, 'frame_end': 2435},
#    {'frame_start': 2466, 'frame_end': 2506},
#    {'frame_start': 2538, 'frame_end': 2543},
#    {'frame_start': 2585, 'frame_end': 2596},
#    {'frame_start': 3641, 'frame_end': 3670},
#    {'frame_start': 3684, 'frame_end': 3707},
#    {'frame_start': 5127, 'frame_end': 5168},
#    {'frame_start': 5197, 'frame_end': 5229},
#    {'frame_start': 5246, 'frame_end': 5273},
#    {'frame_start': 5294, 'frame_end': 5359},
#    {'frame_start': 5405, 'frame_end': 5436},
#    {'frame_start': 5460, 'frame_end': 5498},
#    {'frame_start': 5591, 'frame_end': 5627},
#    {'frame_start': 5650, 'frame_end': 5712},
#    {'frame_start': 5763, 'frame_end': 5812},
#    {'frame_start': 5833, 'frame_end': 5844},
#    {'frame_start': 5853, 'frame_end': 5921},
#    {'frame_start': 5943, 'frame_end': 5956},
#    {'frame_start': 5995, 'frame_end': 6105},
#    {'frame_start': 6178, 'frame_end': 6204},
#    {'frame_start': 6327, 'frame_end': 6363}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 1842, 'frame_end': 1857},
#      {'frame_start': 1878, 'frame_end': 1922},
#      {'frame_start': 2071, 'frame_end': 2235},
#      {'frame_start': 2283, 'frame_end': 2295},
#      {'frame_start': 2328, 'frame_end': 2337},
#      {'frame_start': 2419, 'frame_end': 2435},
#      {'frame_start': 2466, 'frame_end': 2506},
#      {'frame_start': 2538, 'frame_end': 2543},
#      {'frame_start': 2585, 'frame_end': 2596},
#      {'frame_start': 3641, 'frame_end': 3670},
#      {'frame_start': 3684, 'frame_end': 3707},
#      {'frame_start': 5127, 'frame_end': 5168},
#      {'frame_start': 5197, 'frame_end': 5229},
#      {'frame_start': 5246, 'frame_end': 5273},
#      {'frame_start': 5294, 'frame_end': 5359},
#      {'frame_start': 5405, 'frame_end': 5436},
#      {'frame_start': 5460, 'frame_end': 5498},
#      {'frame_start': 5591, 'frame_end': 5627},
#      {'frame_start': 5650, 'frame_end': 5712},
#      {'frame_start': 5763, 'frame_end': 5812},
#      {'frame_start': 5833, 'frame_end': 5844},
#      {'frame_start': 5853, 'frame_end': 5921},
#      {'frame_start': 5943, 'frame_end': 5956},
#      {'frame_start': 5995, 'frame_end': 6105},
#      {'frame_start': 6178, 'frame_end': 6204},
#      {'frame_start': 6327, 'frame_end': 6363}]}}},
#  '3': {'name': '',
#   'type': 'hands_using_wheel/both',
#   'frame_intervals': [{'frame_start': 28, 'frame_end': 515},
#    {'frame_start': 906, 'frame_end': 1315},
#    {'frame_start': 1542, 'frame_end': 2944},
#    {'frame_start': 3235, 'frame_end': 3400},
#    {'frame_start': 3884, 'frame_end': 4238},
#    {'frame_start': 4571, 'frame_end': 6261},
#    {'frame_start': 6354, 'frame_end': 6487},
#    {'frame_start': 6541, 'frame_end': 6601},
#    {'frame_start': 6965, 'frame_end': 7137}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 28, 'frame_end': 515},
#      {'frame_start': 906, 'frame_end': 1315},
#      {'frame_start': 1542, 'frame_end': 2944},
#      {'frame_start': 3235, 'frame_end': 3400},
#      {'frame_start': 3884, 'frame_end': 4238},
#      {'frame_start': 4571, 'frame_end': 6261},
#      {'frame_start': 6354, 'frame_end': 6487},
#      {'frame_start': 6541, 'frame_end': 6601},
#      {'frame_start': 6965, 'frame_end': 7137}]}}},
#  '4': {'name': '',
#   'type': 'hands_using_wheel/only_right',
#   'frame_intervals': [{'frame_start': 1316, 'frame_end': 1541},
#    {'frame_start': 2945, 'frame_end': 3234},
#    {'frame_start': 4239, 'frame_end': 4570},
#    {'frame_start': 6602, 'frame_end': 6964}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 1316, 'frame_end': 1541},
#      {'frame_start': 2945, 'frame_end': 3234},
#      {'frame_start': 4239, 'frame_end': 4570},
#      {'frame_start': 6602, 'frame_end': 6964}]}}},
#  '5': {'name': '',
#   'type': 'hands_using_wheel/only_left',
#   'frame_intervals': [{'frame_start': 516, 'frame_end': 905},
#    {'frame_start': 3401, 'frame_end': 3883},
#    {'frame_start': 6262, 'frame_end': 6353},
#    {'frame_start': 6488, 'frame_end': 6540}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 516, 'frame_end': 905},
#      {'frame_start': 3401, 'frame_end': 3883},
#      {'frame_start': 6262, 'frame_end': 6353},
#      {'frame_start': 6488, 'frame_end': 6540}]}}},
#  '6': {'name': '',
#   'type': 'hand_on_gear/hand_on_gear',
#   'frame_intervals': [{'frame_start': 6266, 'frame_end': 6343},
#    {'frame_start': 6365, 'frame_end': 6366}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 6266, 'frame_end': 6343},
#      {'frame_start': 6365, 'frame_end': 6366}]}}},
#  '7': {'name': '',
#   'type': 'driver_actions/safe_drive',
#   'frame_intervals': [{'frame_start': 19, 'frame_end': 514},
#    {'frame_start': 906, 'frame_end': 1320},
#    {'frame_start': 1539, 'frame_end': 1852},
#    {'frame_start': 1885, 'frame_end': 1897},
#    {'frame_start': 1938, 'frame_end': 2032},
#    {'frame_start': 2069, 'frame_end': 2084},
#    {'frame_start': 2110, 'frame_end': 2174},
#    {'frame_start': 2210, 'frame_end': 2271},
#    {'frame_start': 2301, 'frame_end': 2329},
#    {'frame_start': 2357, 'frame_end': 2480},
#    {'frame_start': 2503, 'frame_end': 2947},
#    {'frame_start': 3242, 'frame_end': 3400},
#    {'frame_start': 3880, 'frame_end': 4242},
#    {'frame_start': 4570, 'frame_end': 5106},
#    {'frame_start': 5150, 'frame_end': 5211},
#    {'frame_start': 5256, 'frame_end': 5295},
#    {'frame_start': 5328, 'frame_end': 5345},
#    {'frame_start': 5368, 'frame_end': 5518},
#    {'frame_start': 5551, 'frame_end': 5595},
#    {'frame_start': 5617, 'frame_end': 5714},
#    {'frame_start': 5735, 'frame_end': 5753},
#    {'frame_start': 5814, 'frame_end': 5856},
#    {'frame_start': 5911, 'frame_end': 6260},
#    {'frame_start': 6348, 'frame_end': 6604},
#    {'frame_start': 6964, 'frame_end': 7135}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 19, 'frame_end': 514},
#      {'frame_start': 906, 'frame_end': 1320},
#      {'frame_start': 1539, 'frame_end': 1852},
#      {'frame_start': 1885, 'frame_end': 1897},
#      {'frame_start': 1938, 'frame_end': 2032},
#      {'frame_start': 2069, 'frame_end': 2084},
#      {'frame_start': 2110, 'frame_end': 2174},
#      {'frame_start': 2210, 'frame_end': 2271},
#      {'frame_start': 2301, 'frame_end': 2329},
#      {'frame_start': 2357, 'frame_end': 2480},
#      {'frame_start': 2503, 'frame_end': 2947},
#      {'frame_start': 3242, 'frame_end': 3400},
#      {'frame_start': 3880, 'frame_end': 4242},
#      {'frame_start': 4570, 'frame_end': 5106},
#      {'frame_start': 5150, 'frame_end': 5211},
#      {'frame_start': 5256, 'frame_end': 5295},
#      {'frame_start': 5328, 'frame_end': 5345},
#      {'frame_start': 5368, 'frame_end': 5518},
#      {'frame_start': 5551, 'frame_end': 5595},
#      {'frame_start': 5617, 'frame_end': 5714},
#      {'frame_start': 5735, 'frame_end': 5753},
#      {'frame_start': 5814, 'frame_end': 5856},
#      {'frame_start': 5911, 'frame_end': 6260},
#      {'frame_start': 6348, 'frame_end': 6604},
#      {'frame_start': 6964, 'frame_end': 7135}]}}},
#  '8': {'name': '',
#   'type': 'driver_actions/radio',
#   'frame_intervals': [{'frame_start': 515, 'frame_end': 905},
#    {'frame_start': 3401, 'frame_end': 3879}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 515, 'frame_end': 905},
#      {'frame_start': 3401, 'frame_end': 3879}]}}},
#  '9': {'name': '',
#   'type': 'driver_actions/drinking',
#   'frame_intervals': [{'frame_start': 1367, 'frame_end': 1466},
#    {'frame_start': 2993, 'frame_end': 3173},
#    {'frame_start': 4390, 'frame_end': 4514},
#    {'frame_start': 6746, 'frame_end': 6887}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 1367, 'frame_end': 1466},
#      {'frame_start': 2993, 'frame_end': 3173},
#      {'frame_start': 4390, 'frame_end': 4514},
#      {'frame_start': 6746, 'frame_end': 6887}]}}},
#  '10': {'name': '',
#   'type': 'driver_actions/reach_side',
#   'frame_intervals': [{'frame_start': 1321, 'frame_end': 1366},
#    {'frame_start': 1467, 'frame_end': 1538},
#    {'frame_start': 2948, 'frame_end': 2992},
#    {'frame_start': 3174, 'frame_end': 3241},
#    {'frame_start': 4243, 'frame_end': 4300},
#    {'frame_start': 4515, 'frame_end': 4569},
#    {'frame_start': 6605, 'frame_end': 6667},
#    {'frame_start': 6888, 'frame_end': 6963}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 1321, 'frame_end': 1366},
#      {'frame_start': 1467, 'frame_end': 1538},
#      {'frame_start': 2948, 'frame_end': 2992},
#      {'frame_start': 3174, 'frame_end': 3241},
#      {'frame_start': 4243, 'frame_end': 4300},
#      {'frame_start': 4515, 'frame_end': 4569},
#      {'frame_start': 6605, 'frame_end': 6667},
#      {'frame_start': 6888, 'frame_end': 6963}]}}},
#  '11': {'name': '',
#   'type': 'driver_actions/talking_to_passenger',
#   'frame_intervals': [{'frame_start': 1853, 'frame_end': 1884},
#    {'frame_start': 1898, 'frame_end': 1937},
#    {'frame_start': 2033, 'frame_end': 2068},
#    {'frame_start': 2085, 'frame_end': 2109},
#    {'frame_start': 2175, 'frame_end': 2209},
#    {'frame_start': 2272, 'frame_end': 2300},
#    {'frame_start': 2330, 'frame_end': 2356},
#    {'frame_start': 2481, 'frame_end': 2502},
#    {'frame_start': 5107, 'frame_end': 5149},
#    {'frame_start': 5212, 'frame_end': 5255},
#    {'frame_start': 5296, 'frame_end': 5327},
#    {'frame_start': 5346, 'frame_end': 5367},
#    {'frame_start': 5519, 'frame_end': 5550},
#    {'frame_start': 5596, 'frame_end': 5616},
#    {'frame_start': 5715, 'frame_end': 5734},
#    {'frame_start': 5754, 'frame_end': 5813},
#    {'frame_start': 5857, 'frame_end': 5910}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 1853, 'frame_end': 1884},
#      {'frame_start': 1898, 'frame_end': 1937},
#      {'frame_start': 2033, 'frame_end': 2068},
#      {'frame_start': 2085, 'frame_end': 2109},
#      {'frame_start': 2175, 'frame_end': 2209},
#      {'frame_start': 2272, 'frame_end': 2300},
#      {'frame_start': 2330, 'frame_end': 2356},
#      {'frame_start': 2481, 'frame_end': 2502},
#      {'frame_start': 5107, 'frame_end': 5149},
#      {'frame_start': 5212, 'frame_end': 5255},
#      {'frame_start': 5296, 'frame_end': 5327},
#      {'frame_start': 5346, 'frame_end': 5367},
#      {'frame_start': 5519, 'frame_end': 5550},
#      {'frame_start': 5596, 'frame_end': 5616},
#      {'frame_start': 5715, 'frame_end': 5734},
#      {'frame_start': 5754, 'frame_end': 5813},
#      {'frame_start': 5857, 'frame_end': 5910}]}}},
#  '12': {'name': '',
#   'type': 'driver_actions/change_gear',
#   'frame_intervals': [{'frame_start': 6261, 'frame_end': 6347}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 6261, 'frame_end': 6347}]}}},
#  '13': {'name': '',
#   'type': 'driver_actions/unclassified',
#   'frame_intervals': [{'frame_start': 4301, 'frame_end': 4389},
#    {'frame_start': 6668, 'frame_end': 6745}],
#   'ontology_uid': '0',
#   'action_data_pointers': {'annotated': {'type': 'text',
#     'frame_intervals': [{'frame_start': 4301, 'frame_end': 4389},
#      {'frame_start': 6668, 'frame_end': 6745}]}}}}

# %%
[o["type"] for o in j["vcd"]["actions"].values()]
# Out:
# ['gaze_on_road/looking_road',
#  'gaze_on_road/not_looking_road',
#  'talking/talking',
#  'hands_using_wheel/both',
#  'hands_using_wheel/only_right',
#  'hands_using_wheel/only_left',
#  'hand_on_gear/hand_on_gear',
#  'driver_actions/safe_drive',
#  'driver_actions/radio',
#  'driver_actions/drinking',
#  'driver_actions/reach_side',
#  'driver_actions/talking_to_passenger',
#  'driver_actions/change_gear',
#  'driver_actions/unclassified']

# %% [markdown]
# ## 1.3 Convert Videos To Frames For Furthur Processing

# %%
import cv2
import os
import glob

# %%
def save_frames(video_file, des_fol):
    video_name = video_file.split("\\")[-1].split(".")[0] # Get the video name without the other part
    cap = cv2.VideoCapture(video_file) # Start the video capture
    frame_count = 0
    while cap.isOpened(): # Until all the frames are over loop though those
        ret, frame = cap.read()
        if not ret:
            break
        frame_path = os.path.join(des_fol, f"img_{frame_count}.png") # Save RGB images
        cv2.imwrite(frame_path, frame)
        frame_count+=1
    cap.release()
    cv2.destroyAllWindows()

# %%
output_directory = "s1/frames"
video_file = "s1/gB_9_s1_2019-03-07T16;36;24+01;00_rgb_body.mp4"
save_frames(video_file, output_directory)

# %% [markdown]
# ## 1.4 Create Tabular Data Mapping Images and Respective Actions

# %%
import json
import pandas as pd

# %%
with open("s1/gB_9_s1_2019-03-07T16;36;24+01;00_rgb_ann_distraction.json", "r") as f:
    j = json.load(f)

# %%
actions = [o["type"] for o in j["vcd"]["actions"].values()]
actions # available labels
# Out:
# ['gaze_on_road/looking_road',
#  'gaze_on_road/not_looking_road',
#  'talking/talking',
#  'hands_using_wheel/both',
#  'hands_using_wheel/only_right',
#  'hands_using_wheel/only_left',
#  'hand_on_gear/hand_on_gear',
#  'driver_actions/safe_drive',
#  'driver_actions/radio',
#  'driver_actions/drinking',
#  'driver_actions/reach_side',
#  'driver_actions/talking_to_passenger',
#  'driver_actions/change_gear',
#  'driver_actions/unclassified']

# %%
actions_considered = ['driver_actions/safe_drive',
 'driver_actions/radio',
 'driver_actions/drinking',
 'driver_actions/reach_side',
 'driver_actions/talking_to_passenger',
 'driver_actions/change_gear',
 'driver_actions/unclassified'] # Taken only lables related to body camera
df = pd.DataFrame(columns=["frameid", "classname"])
for act in j["vcd"]["actions"].values(): # For each action types
    type_ = act["type"]
    if type_ not in actions_considered: # If not available in the action considered then not processing that
        continue
    intervals = act["frame_intervals"]
    for interval in intervals: # for rach frames keep record of what the driver is doing
        fStart = interval["frame_start"]
        fEnd = interval["frame_end"]
        for i in range(fStart, fEnd+1):
            df.loc[i, "classname"]=type_ # mark that specific frame for related action
df["frameid"] = df.index
df.fillna(0, inplace=True)
df
# Out:
#       frameid                    classname
# 19         19    driver_actions/safe_drive
# 20         20    driver_actions/safe_drive
# 21         21    driver_actions/safe_drive
# 22         22    driver_actions/safe_drive
# 23         23    driver_actions/safe_drive
# ...       ...                          ...
# 6741     6741  driver_actions/unclassified
# 6742     6742  driver_actions/unclassified
# 6743     6743  driver_actions/unclassified
# 6744     6744  driver_actions/unclassified
# 6745     6745  driver_actions/unclassified
#
# [7117 rows x 2 columns]

# %%
df = df.sort_values(by='frameid')
df
# Out:
#       frameid                  classname
# 19         19  driver_actions/safe_drive
# 20         20  driver_actions/safe_drive
# 21         21  driver_actions/safe_drive
# 22         22  driver_actions/safe_drive
# 23         23  driver_actions/safe_drive
# ...       ...                        ...
# 7131     7131  driver_actions/safe_drive
# 7132     7132  driver_actions/safe_drive
# 7133     7133  driver_actions/safe_drive
# 7134     7134  driver_actions/safe_drive
# 7135     7135  driver_actions/safe_drive
#
# [7117 rows x 2 columns]

# %%
df["img"] = df["frameid"].apply(lambda x : f"img_{str(x)}.jpg")
df
# Out:
#       frameid                  classname           img
# 19         19  driver_actions/safe_drive    img_19.jpg
# 20         20  driver_actions/safe_drive    img_20.jpg
# 21         21  driver_actions/safe_drive    img_21.jpg
# 22         22  driver_actions/safe_drive    img_22.jpg
# 23         23  driver_actions/safe_drive    img_23.jpg
# ...       ...                        ...           ...
# 7131     7131  driver_actions/safe_drive  img_7131.jpg
# 7132     7132  driver_actions/safe_drive  img_7132.jpg
# 7133     7133  driver_actions/safe_drive  img_7133.jpg
# 7134     7134  driver_actions/safe_drive  img_7134.jpg
# 7135     7135  driver_actions/safe_drive  img_7135.jpg
#
# [7117 rows x 3 columns]

# %%
df.to_csv("driver_imgs_list.csv")
